# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("SRC/MASTER.xlsx")

# %%
df.head()
# Out:
#                                         message_text  \
# 0  Hola buenas una consulta yo estoy matriculado ...
# 1  Buenas tardes, este curso personalizado se pue...
# 2  Hola! Quería preguntar sobre las clases online...
# 3  Hola, para realizar cotizaciones es posible ha...
# 4  Quisiera cotizar por un curso en modalidad grupal
#
#                                     palabras_activas      label_regla  \
# 0               ['presencial', 'consulta', 'alumno']  modalidad_curso
# 1                                ['curso', 'online']  modalidad_curso
# 2  ['clase', 'online', 'sobre', 'como', 'comenzar...  modalidad_curso
# 3                         ['presencial', 'realizar']  modalidad_curso
# 4                             ['curso', 'modalidad']  modalidad_curso
#
#        golden_label             extra
# 0             otros               NaN
# 1  curso_especifico               NaN
# 2         modalidad               NaN
# 3      info_general               NaN
# 4      precio_curso  curso_por_perfil

# %%
df = df.dropna(subset=["message_text", "golden_label"])
df = df.reset_index(drop=True)

# %%
labels_a_fusionar = [
    "examen",
    "canal_contacto",
    "curso_especifico",
    "modalidad",
    "otros"
]

df["golden_label"] = df["golden_label"].replace(labels_a_fusionar, "info_general")

# %%
df["golden_label"].value_counts().plot(kind="barh", figsize=(8,6))
# Out:
# <Axes: ylabel='golden_label'>

# %%
import re

def clean_text(text):

    text = text.lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"[^a-záéíóúñ0-9 ]", " ", text)
    text = re.sub(r"\s+", " ", text)

    return text.strip()

df["text_clean"] = df["message_text"].apply(clean_text)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df["text_clean"],
    df["golden_label"],
    test_size=0.2,
    stratify=df["golden_label"],
    random_state=42
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    ngram_range=(1,2),
    min_df=3
)

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    max_iter=300,
    n_jobs=-1
)

model.fit(X_train_vec, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       8 model.fit(X_train_vec, y_train)
#       9 pred = model.predict(X_test_vec)
# ---> 10 print(classification_report(y_test, pred))
#
# NameError: name 'classification_report' is not defined

# %%
from sklearn.metrics import classification_report

pred = model.predict(X_test_vec)

print(classification_report(y_test, pred))
# Out:
#                   precision    recall  f1-score   support
#
#           basura       0.68      0.91      0.78       265
# curso_por_perfil       0.74      0.56      0.64        57
#          horario       0.73      0.51      0.60        81
#     info_general       0.58      0.53      0.55       152
#      inscripcion       0.87      0.59      0.71       101
#     precio_curso       0.83      0.90      0.86       284
#          soporte       0.50      0.20      0.29        50
#
#         accuracy                           0.73       990
#        macro avg       0.70      0.60      0.63       990
#     weighted avg       0.72      0.73      0.71       990

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

labels = sorted(df["golden_label"].unique())

cm = confusion_matrix(y_test, pred, labels=labels)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="magma",
    xticklabels=labels,
    yticklabels=labels
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Intent Classifier")

plt.show()

# %%
import numpy as np
import pandas as pd

feature_names = vectorizer.get_feature_names_out()

for i, label in enumerate(model.classes_):

    coef = model.coef_[i]

    top = np.argsort(coef)[-15:]

    print(f"\nIntent: {label}")
    print("-"*40)

    for j in reversed(top):
        print(feature_names[j], round(coef[j],3))
# Out:
# Intent: basura
# ----------------------------------------
# te 2.185
# tu 2.014
# britanicoconce 2.005
# sent 1.86
# la 1.852
# sent an 1.843
# attachment 1.843
# an attachment 1.843
# an 1.843
# nuestros 1.34
# participar 1.292
# pantallazo 1.253
# envío 1.239
# por 1.217
# que no 1.184
#
# Intent: curso_por_perfil
# ----------------------------------------
# años 4.719
# edad 2.437
# niños 2.373
# para 2.324
# adultos 2.08
# de años 1.95
# para niños 1.877
# hijo 1.728
# curso 1.725
# mi 1.628
# teenagers 1.528
# que edad 1.481
# mi hijo 1.478
# adulto 1.467
# com 1.427
#
# Intent: horario
# ----------------------------------------
# horarios 3.648
# horario 3.272
# fecha 2.577
# los horarios 2.501
# las 2.3
# cuando 2.186
# clases 2.116
# el horario 1.886
# comienzan 1.758
# los 1.495
# día 1.424
# semana 1.358
# martes 1.336
# las clases 1.327
# clases en 1.308
#
# Intent: info_general
# ----------------------------------------
# online 2.858
# cursos 1.78
# modalidad 1.755
# presenciales 1.706
# certificación 1.624
# libro 1.567
# examen 1.556
# cae 1.502
# presencial 1.429
# info 1.41
# tienen 1.359
# sobre 1.359
# curso 1.159
# son 1.147
# básico 1.128
#
# Intent: inscripcion
# ----------------------------------------
# inscribirme 3.246
# entrevista 2.786
# matricular 2.599
# hora 2.576
# matricularme 2.372
# ir 2.22
# evaluación 2.166
# inscribir 2.081
# agendar 1.646
# hasta 1.636
# matrículas 1.626
# para 1.585
# la evaluación 1.573
# la entrevista 1.549
# aún 1.29
#
# Intent: precio_curso
# ----------------------------------------
# valores 8.996
# valor 8.063
# el valor 3.401
# los valores 3.397
# pagar 3.353
# precio 3.351
# precios 2.998
# descuento 2.683
# información 2.654
# cuánto 2.167
# pago 2.084
# cotizar 2.023
# valor de 1.994
# del curso 1.909
# el precio 1.82
#
# Intent: soporte
# ----------------------------------------
# correo 2.789
# hay clases 1.813
# no 1.755
# certificado 1.739
# me 1.62
# enviar 1.562
# hoy 1.453
# link 1.381
# clase 1.238
# la 1.227
# clases 1.209
# sábado 1.187
# el 1.17
# envié 1.113
# he 1.073

# %%
import joblib

joblib.dump(model, "models/intent_model.pkl")
joblib.dump(vectorizer, "models/vectorizer.pkl")
# Out:
# ['models/vectorizer.pkl']

# %%
import json

labels = model.classes_.tolist()

with open("models/intent_labels.json", "w") as f:
    json.dump(labels, f)

# %%
import joblib

model_loaded = joblib.load("models/intent_model.pkl")
vectorizer_loaded = joblib.load("models/vectorizer.pkl")

print(model_loaded.classes_)
# Out:
# ['basura' 'curso_por_perfil' 'horario' 'info_general' 'inscripcion'
#  'precio_curso' 'soporte']

# %%
def test(text):

    vec = vectorizer_loaded.transform([text])

    probs = model_loaded.predict_proba(vec)

    idx = probs.argmax()

    intent = model_loaded.classes_[idx]

    return intent, probs.max()

test("hola cuanto cuesta el curso")
# Out:
# ('precio_curso', 0.6316964372004619)
